# %% [markdown]
# ## Overview of Data

# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath('../utils'))

from data_visualizations import *

data = pd.read_csv('../data/dataset2cleaned.csv')
important_features = ['danceability', 'energy', 'acousticness', 'instrumentalness', 'valence', 'explicit']

# %%
genresImportantAttributes(data, important_features)

# %%
plotFeatureDistributions(data, important_features)

# %% [markdown]
# ## Deeper EDA

# %%
# Correlation matrix
important_features = ['danceability', 'energy', 'acousticness', 'instrumentalness', 'valence', 'explicit']

plotCorrelationHeatmap(data, important_features)

# %%
# Loop through each feature in `important_features`
plotUnivariateAnalysis(data, important_features)

# %%
plotClassesCount(data, 'genre')
# Out:
# genre
# classical    1000
# country      1000
# jazz         1000
# pop          1000
# rock         1000
# Name: count, dtype: int64
